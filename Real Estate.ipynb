# %% [markdown]
# # Task6: Predicting Real Estate House Prices

# %% [markdown]
# ## This task is provided to test your understanding of building a Linear Regression model for a provided dataset

# %% [markdown]
# ### Dataset: Real_estate.csv

# %% [markdown]
# ### Import the necessary libraries
# #### Hint: Also import seaborn
# #### citation:
#         - https://seaborn.pydata.org/generated/seaborn.regplot.html
#         - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %% [markdown]
# ### Read the csv data into a pandas dataframe and display the first 5 samples

# %%
df = pd.read_csv('Real estate.csv')
df.head()
# Out:
#    No  X1 transaction date  X2 house age
# 0   1             2012.917          32.0  \
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores
# 0                                84.87882                               10  \
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# ### Show more information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# ### Find how many samples are there and how many columns are there in the dataset

# %%
df.shape
# Out:
# (414, 8)

# %% [markdown]
# ### What are the features available in the dataset?

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ### Check if any features have missing data

# %%
null_data = df.isnull().sum()
print(nul_data)
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# ### Group all the features as dependent features in X

# %%
x = df[['No', 'X1 transaction date', 'X2 house age',
       'X3 distance to the nearest MRT station',
       'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',]]

x
# Out:
#       No  X1 transaction date  X2 house age
# 0      1             2012.917          32.0  \
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores
# 0                                  84.87882                               10  \
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %% [markdown]
# ### Group feature(s) as independent features in y

# %%
y = df['Y house price of unit area']

y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %% [markdown]
# ### Split the dataset into train and test data

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Choose the model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Create an Estimator object

# %%
lm = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Apply the model

# %%
prediction = lm.predict(X_test)

prediction
# Out:
# array([46.63500169, 40.24113343, 43.27451225, 39.42392538, 26.41737818,
#        46.7590668 , 44.373057  , 47.01617107, 24.73302641, 55.20723326,
#        35.24453596, 36.78602271, 36.4558036 , 24.60160749, 36.61256768,
#        33.53862681, 45.03590136, 44.58139926, 28.94545078, 44.76056711,
#         0.46682603, 36.54865933, 47.03676744, 46.0376176 ,  9.80819889,
#        38.86395109, 11.68678066, 43.58101045, 36.53440728, 38.39504924,
#        14.01814402, 40.52535499, 36.19016624, 27.92929379, 47.6811978 ,
#        31.72262215, 50.12022329, 11.90992025, 49.7289872 , 39.96859915,
#        40.30835716, 40.32736106, 48.95145733, 37.02885946, 39.3123335 ,
#        47.1579367 , 43.1837143 , 19.4356479 , 46.5513857 , 45.01065879,
#        47.95387969, 47.84393899, 42.13580911, 42.63926258, 36.87174334,
#        14.96775073, 38.47796057, 34.52383209, 29.14602677, 47.16202053,
#        31.67605557, 34.02453236, 14.45447017,  8.47825601,  8.65310317,
# ...

# %% [markdown]
# ### Display the coefficients

# %%
lm.coef_
# Out:
# array([-6.25951905e-03,  5.85978276e+00, -2.39516367e-01, -5.22951335e-03,
#         1.06493330e+00,  2.36128176e+02, -5.44687080e+01])

# %% [markdown]
# ### Find how well the trained model did with testing data

# %%
print('MAE :', metrics.mean_absolute_error(y_test,prediction))
print('MSE : ', metrics.mean_squared_error(y_test, prediction))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_test,prediction)))
# Out:
# MAE : 6.26642283309245
# MSE :  74.70865668115886
# RMSE : 8.643416956340754

# %% [markdown]
# # OR

# %%
mse = mean_squared_error(y_test, prediction)
r2 = r2_score(y_test, prediction)

print('Mean squared error is:',mse)
print('Root mean squared error is : ',r2)
# Out:
# Mean squared error is: 74.70865668115886
# Root mean squared error is :  0.5532450005316303

# %% [markdown]
# ### Plot House Age Vs Price
# #### Hint: Use regplot in sns

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
sns.regplot(data = df , x= 'X2 house age', y= 'Y house price of unit area', marker='o', color='blue')
# Out:
# <Axes: xlabel='X2 house age', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Distance to MRT station Vs Price

# %%
sns.regplot(data = df , x=  'Y house price of unit area' , y='X3 distance to the nearest MRT station', marker='o')
# Out:
# <Axes: xlabel='Y house price of unit area', ylabel='X3 distance to the nearest MRT station'>

# %% [markdown]
# ### Plot Number of Convienience Stores Vs Price

# %%
sns.regplot(data = df , x=  'Y house price of unit area' , y= 'X4 number of convenience stores' , marker='o')
# Out:
# <Axes: xlabel='Y house price of unit area', ylabel='X4 number of convenience stores'>
